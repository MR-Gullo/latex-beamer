# %% [markdown]
# # 🎯 CS12 Ch 1-4 Test Review

# %% [markdown]
# ## Exercise 1: Program Structure
#
# **Task:** Label each part of this C++ program.
#
# ```cpp
# #include <iostream>
# using namespace std;
#
# const float pi = 3.14159;
#
# int main()
# {
#     float diameter = 13.5;
#
#     cout << "Area is "
#          << pi * (diameter/2) * (diameter/2)
#          << endl;
#
#     return 0;
# }
# ```
#
# Write the 5 parts:
# 1. _______________
# 2. _______________
# 3. _______________
# 4. _______________
# 5. _______________

# %% [markdown]
# ## Exercise 2: Data Type Identification
#
# **Task:** Match each value to its correct C++ data type.
#
# | Value | Data Type |
# |-------|----------|
# | `42` | |
# | `3.14` | |
# | `'A'` | |
# | `true` | |
# | `-17` | |
# | `0.005` | |
# | `'\n'` | |
# | `false` | |
#
# Options: `int`, `float`, `char`, `bool`

# %% [markdown]
# ## Exercise 3: Integer vs Float Division
#
# **Task:** Calculate the result. Show if it's integer or float division.
#
# | Expression | Result | Division Type |
# |------------|--------|---------------|
# | `7 / 2` | | |
# | `7.0 / 2` | | |
# | `7 / 2.0` | | |
# | `10 / 4` | | |
# | `10.0 / 4.0` | | |
# | `15 / 6` | | |

# %% [markdown]
# **Check your answers:**
#
# ```cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#     cout << "7 / 2 = " << 7 / 2 << endl;
#     cout << "7.0 / 2 = " << 7.0 / 2 << endl;
#     cout << "7 / 2.0 = " << 7 / 2.0 << endl;
#     cout << "10 / 4 = " << 10 / 4 << endl;
#     cout << "10.0 / 4.0 = " << 10.0 / 4.0 << endl;
#     cout << "15 / 6 = " << 15 / 6 << endl;
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Exercise 4: Math Operations
#
# **Task:** Calculate these expressions.
#
# | Expression | Result |
# |------------|--------|
# | `5 + 3 * 2` | |
# | `(5 + 3) * 2` | |
# | `10 % 3` | |
# | `17 % 5` | |
# | `pow(2, 3)` | |
# | `sqrt(16)` | |
# | `pow(5, 2)` | |

# %% [markdown]
# **Check your answers:**
#
# ```cpp
# #include <iostream>
# #include <cmath>
# using namespace std;
#
# int main() {
#     cout << "5 + 3 * 2 = " << 5 + 3 * 2 << endl;
#     cout << "(5 + 3) * 2 = " << (5 + 3) * 2 << endl;
#     cout << "10 % 3 = " << 10 % 3 << endl;
#     cout << "17 % 5 = " << 17 % 5 << endl;
#     cout << "pow(2, 3) = " << pow(2, 3) << endl;
#     cout << "sqrt(16) = " << sqrt(16) << endl;
#     cout << "pow(5, 2) = " << pow(5, 2) << endl;
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Exercise 5: Distance Formula
#
# **Formula:** $d = \sqrt{(x_2 - x_1)^2 + (y_2 - y_1)^2}$
#
# **Task:** Calculate distance between these points.
#
# 1. Point A: (0, 0), Point B: (3, 4)
# 2. Point A: (1, 2), Point B: (4, 6)
# 3. Point A: (-2, 3), Point B: (1, -1)

# %% [markdown]
# **Complete this code:**
#
# ```cpp
# #include <iostream>
# #include <cmath>
# using namespace std;
#
# int main() {
#     float x1, y1, x2, y2, distance;
#
#     // Problem 1
#     x1 = 0; y1 = 0;
#     x2 = 3; y2 = 4;
#     distance = // TODO: Your calculation here
#     cout << "Distance 1: " << distance << endl;
#
#     // Problem 2
#     x1 = 1; y1 = 2;
#     x2 = 4; y2 = 6;
#     distance = // TODO: Your calculation here
#     cout << "Distance 2: " << distance << endl;
#
#     // Problem 3
#     x1 = -2; y1 = 3;
#     x2 = 1; y2 = -1;
#     distance = // TODO: Your calculation here
#     cout << "Distance 3: " << distance << endl;
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Exercise 6: Slope Formula
#
# **Formula:** $\text{slope} = \frac{y_2 - y_1}{x_2 - x_1}$
#
# **Task:** Calculate slope between these points.
#
# 1. Point A: (2, 3), Point B: (5, 9)
# 2. Point A: (0, 0), Point B: (4, 8)
# 3. Point A: (1, 5), Point B: (3, 1)

# %% [markdown]
# **Complete this code:**
#
# ```cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#     float x1, y1, x2, y2, slope;
#
#     // Problem 1
#     x1 = 2; y1 = 3;
#     x2 = 5; y2 = 9;
#     slope = // TODO: Your calculation here
#     cout << "Slope 1: " << slope << endl;
#
#     // Problem 2
#     x1 = 0; y1 = 0;
#     x2 = 4; y2 = 8;
#     slope = // TODO: Your calculation here
#     cout << "Slope 2: " << slope << endl;
#
#     // Problem 3
#     x1 = 1; y1 = 5;
#     x2 = 3; y2 = 1;
#     slope = // TODO: Your calculation here
#     cout << "Slope 3: " << slope << endl;
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Exercise 7: ASCII Character Math
#
# **Concept:** Characters are numbers. `'A'` = 65, `'a'` = 97. Difference = 32.
#
# **Task:** Convert these characters.
#
# 1. `'B'` to lowercase
# 2. `'Z'` to lowercase
# 3. `'m'` to uppercase

# %% [markdown]
# **Complete this code:**
#
# ```cpp
# #include <iostream>
# using namespace std;
#
# int main() {
#     char uppercase, lowercase;
#
#     // Check ASCII values
#     cout << "ASCII value of 'A': " << (int)'A' << endl;
#     cout << "ASCII value of 'a': " << (int)'a' << endl;
#     cout << "Difference: " << (int)'a' - (int)'A' << endl;
#     cout << endl;
#
#     // Problem 1: 'B' to lowercase
#     uppercase = 'B';
#     lowercase = // TODO: Your calculation here
#     cout << "'B' to lowercase: " << lowercase << endl;
#
#     // Problem 2: 'Z' to lowercase
#     uppercase = 'Z';
#     lowercase = // TODO: Your calculation here
#     cout << "'Z' to lowercase: " << lowercase << endl;
#
#     // Problem 3: 'm' to uppercase
#     lowercase = 'm';
#     uppercase = // TODO: Your calculation here
#     cout << "'m' to uppercase: " << uppercase << endl;
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Exercise 8: Radioactive Decay
#
# **Formula:** $\text{remaining} = (\text{original}) \times e^{-0.00012t}$
#
# **Task:** Calculate remaining amount.
#
# 1. Original = 100g, time = 1000 years
# 2. Original = 50g, time = 5000 years
# 3. Original = 200g, time = 10000 years

# %% [markdown]
# **Complete this code:**
#
# ```cpp
# #include <iostream>
# #include <cmath>
# using namespace std;
#
# int main() {
#     float original, time, remaining;
#
#     // Problem 1
#     original = 100;
#     time = 1000;
#     remaining = // TODO: Your calculation here
#     cout << "Remaining after 1000 years: " << remaining << "g" << endl;
#
#     // Problem 2
#     original = 50;
#     time = 5000;
#     remaining = // TODO: Your calculation here
#     cout << "Remaining after 5000 years: " << remaining << "g" << endl;
#
#     // Problem 3
#     original = 200;
#     time = 10000;
#     remaining = // TODO: Your calculation here
#     cout << "Remaining after 10000 years: " << remaining << "g" << endl;
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Exercise 9: cin Practice
#
# **Task:** Write what each cin statement does.
#
# ```cpp
# int age;
# cout << "Enter age: ";
# cin >> age;
# ```
#
# What does `cin >> age;` do?
#
# ```cpp
# float price;
# cin >> price;
# ```
#
# What type of data can be stored in `price`?
#
# ```cpp
# char grade;
# cin >> grade;
# ```
#
# What is an example input for this?

# %% [markdown]
# ## Exercise 10: cmath Library
#
# **Task:** Match function to description.
#
# | Function | What it does |
# |----------|-------------|
# | `pow(2, 3)` | |
# | `sqrt(25)` | |
# | `exp(2)` | |
# | `pow(5, 2)` | |
# | `sqrt(100)` | |
#
# Calculate:
# 1. `pow(3, 4)` = ?
# 2. `sqrt(144)` = ?
# 3. `exp(1)` = ?

# %% [markdown]
# **Check your answers:**
#
# ```cpp
# #include <iostream>
# #include <cmath>
# using namespace std;
#
# int main() {
#     cout << "pow(2, 3) = " << pow(2, 3) << endl;
#     cout << "sqrt(25) = " << sqrt(25) << endl;
#     cout << "exp(2) = " << exp(2) << endl;
#     cout << "pow(5, 2) = " << pow(5, 2) << endl;
#     cout << "sqrt(100) = " << sqrt(100) << endl;
#
#     cout << "\nYour calculations:" << endl;
#     cout << "pow(3, 4) = " << pow(3, 4) << endl;
#     cout << "sqrt(144) = " << sqrt(144) << endl;
#     cout << "exp(1) = " << exp(1) << endl;
#
#     return 0;
# }
# ```

# %% [markdown]
# ## Exercise 11: Comments
#
# **Task:** Identify comment type.
#
# ```cpp
# // Calculate area
# float area = l * w;
# ```
# Type: _______________
#
# ```cpp
# /* This calculates
#    the distance */
# ```
# Type: _______________
#
# Write a single-line comment:
#
# Write a multi-line comment:

# %% [markdown]
# ## 🎯 Test Prep Checklist
#
# Can you:
#
# ✅ Name the 5 parts of a C++ program?
#
# ✅ Identify data types (`int`, `float`, `char`, `bool`)?
#
# ✅ Explain integer vs float division?
#
# ✅ Use `cin` to get user input?
#
# ✅ Use `pow()`, `sqrt()`, `exp()` from `<cmath>`?
#
# ✅ Calculate distance, slope, and decay?
#
# ✅ Do ASCII character math?
#
# ✅ Write single and multi-line comments?
